# %% [markdown]
# # API Test Notebook
#
# Use this notebook to test the local `/predict` endpoint with exercise feature values.

# %%
import requests

# %%
payload = {
    "age": 32,
    "gender": "Female",
    "weight_kg": 68.1,
    "height_m": 1.66,
    "max_bpm": 167,
    "avg_bpm": 122,
    "resting_bpm": 54,
    "session_duration_hours": 1.11,
    "workout_type": "Cardio",
    "fat_percentage": 33.4,
    "water_intake_liters": 2.3,
    "workout_frequency_days_per_week": 4,
    "experience_level": 2,
    "bmi": 24.71
}

# %%
response = requests.post("http://127.0.0.1:8000/predict", json=payload)
response.status_code, response.json()
# Out:
# (200, {'prediction': 672.4224079398598})
